# %%
import openai
import pandas as pd
import OpenDartReader
import dart_fss 
import numpy as np

# %%
openai.api_key = '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'

# %%
# Generate text
prompt = "What is the weather like in London today?"
completions = openai.Completion.create(
    engine="text-davinci-002",
    prompt=prompt,
    max_tokens=1024,
    n=1,
    stop=None,
    temperature=0.5,
)

# Print the generated text
message = completions.choices[0].text
print(message)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-9-b99183cb8405> in <module>
#       7     n=1,
#       8     stop=None,
# ----> 9     temperature=0.5,
#      10 )
#      11
#
# ~/opt/anaconda3/lib/python3.7/site-packages/openai/api_resources/completion.py in create(cls, *args, **kwargs)
#      23         while True:
#      24             try:
# ---> 25                 return super().create(*args, **kwargs)
#      26             except TryAgain as e:
#      27                 if timeout is not None and time.time() > start + timeout:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/openai/api_resources/abstract/engine_api_resource.py in create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     158             stream=stream,
#     159             request_id=request_id,
# --> 160             request_timeout=request_timeout,
# ...

# %%
https://medium.com/@kaushaltrivedi/building-a-multilingual-translation-tool-with-openai-chatgpt-api-84922c971e95

# %%
https://medium.com/@krishnapiryakm/a-step-by-step-guide-to-using-the-chatgpt-api-in-jupyter-notebooks-c49dabd96398

# %%
# translate a given name in Korean to English

import json
import urllib.request

client_id = "V8EKaXYbn_4hLV5maSiO"
client_secret = "eaOWqDahk4"

def translate_name(input_name):
    
    encText = urllib.parse.quote(input_name)
    url = "https://openapi.naver.com/v1/krdict/romanization?query=" + encText
    1
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200):
        response_body = response.read()
        json_dict = json.loads(response_body.decode('utf-8'))
        result = json_dict['aResult'][0]
        name_items = result['aItems']
        names = [name_item['name'] for name_item in name_items]
        return names
    
    else:
        print("Error Code:" + rescode)

# %%
api_key = 'fe25af1605823b643d82264da06f86c919a8bc57'
dart = OpenDartReader(api_key) 
dart_fss.set_api_key(api_key=api_key)

company_name_search = dart.company_by_name('삼성전자')

# %%
company_name_search[0]['bizr_no']
# Out:
# '1248158485'

# %%
company_name_search[3]
# Out:
# {'status': '000',
#  'message': '정상',
#  'corp_code': '00126380',
#  'corp_name': '삼성전자(주)',
#  'corp_name_eng': 'SAMSUNG ELECTRONICS CO,.LTD',
#  'stock_name': '삼성전자',
#  'stock_code': '005930',
#  'ceo_nm': '한종희, 경계현',
#  'corp_cls': 'Y',
#  'jurir_no': '1301110006246',
#  'bizr_no': '1248100998',
#  'adres': '경기도 수원시 영통구  삼성로 129 (매탄동)',
#  'hm_url': 'www.samsung.com/sec',
#  'ir_url': '',
#  'phn_no': '02-2255-0114',
#  'fax_no': '031-200-7538',
#  'induty_code': '264',
#  'est_dt': '19690113',
#  'acc_mt': '12'}

# %%
company_name_search = dart.company_by_name('삼성전자')

# %%
company_name_search[0]
# Out:
# {'status': '000',
#  'message': '정상',
#  'corp_code': '00258999',
#  'corp_name': '삼성전자 서비스주식회사',
#  'corp_name_eng': 'SAMSUNNG ELECTRONICS SERVICE CO., LTD',
#  'stock_name': '삼성전자서비스',
#  'stock_code': '',
#  'ceo_nm': '송봉섭',
#  'corp_cls': 'E',
#  'jurir_no': '1301110049139',
#  'bizr_no': '1248158485',
#  'adres': '경기도 수원시 영통구 삼성로 290 (원천동)',
#  'hm_url': 'www.samsungsvc.co.kr',
#  'ir_url': '',
#  'phn_no': '031-270-2177',
#  'fax_no': '031-270-2106',
#  'induty_code': '95',
#  'est_dt': '19981027',
#  'acc_mt': '12'}

# %%
# identify the given corporation 

api_key = 'fe25af1605823b643d82264da06f86c919a8bc57'
dart = OpenDartReader(api_key) 
dart_fss.set_api_key(api_key=api_key)

def corp_confirm(corp_name_kor, corp_num):
    
    company_name_search = dart.company_by_name(corp_name_kor)
   
    if len(company_name_search) == 0 :

        print("Please contact at Customer Center")

    else:
        for idx in range(len(company_name_search)):
            temp_corp = company_name_search[idx]
            
            if corp_num == int(temp_corp['bizr_no']):
                corp_confirmed = temp_corp
        
                return corp_confirmed

def corp_info(input_data):

    corp_info_df = pd.DataFrame.from_dict(input_data, orient='index')
    corp_code = input_data['corp_code']
    corp_info_df_ = corp_info_df.drop(index= ['status' , 'message' , 'corp_code' , 'corp_cls' , 'jurir_no' , 'induty_code' , 'est_dt' , 'acc_mt'], axis=1)

    return corp_code, corp_info_df_           


# 사업보고서
def corp_report_info(input_corp, *args, input_year):
    
    report_list = ['조건부자본증권미상환', '미등기임원보수', '회사채미상환', '단기사채미상환', '기업어음미상환', '채무증권발행', '사모자금사용', 
                   '공모자금사용', '임원전체보수승인', '임원전체보수유형', '주식총수', '회계감사', '감사용역', '회계감사용역계약', '사외이사', 
                   '신종자본증권미상환', '증자', '배당', '자기주식', '최대주주', '최대주주변동', '소액주주', '임원', '직원', '임원개인보수', '임원전체보수', '개인별보수', '타법인출자']
    
    element_list = []
    temp_report_list = []

    for element in args:

        if element in report_list:

            element_list.append(element)
            temp_report = dart.report(input_corp, element, input_year)
            temp_report_list.append(temp_report)

    return element_list, temp_report_list


# 주용사항보고서
def corp_event_info(input_corp, *args):

    event_list = ['부도발생', '영업정지', '회생절차', '해산사유', '유상증자', '무상증자', '유무상증자', '감자', 
                  '관리절차개시', '소송', '해외상장결정', '해외상장폐지결정', '해외상장', '해외상장폐지', '전환사채발행', '신주인수권부사채발행', 
                  '교환사채발행', '관리절차중단', '조건부자본증권발행', '자산양수도', '타법인증권양도', '유형자산양도', '유형자산양수', '타법인증권양수', 
                  '영업양도', '영업양수', '자기주식취득신탁계약해지', '자기주식취득신탁계약체결', '자기주식처분', '자기주식취득', '주식교환', '회사분할합병', '회사분할', '회사합병', '사채권양수', '사채권양도결정']
    
    element_list = []
    temp_event_list = []

    for element in args:

        if element in event_list:

            element_list.append(element)
            temp_event = dart.report(input_corp, element)
            temp_event_list.append(temp_event)

    return element_list, temp_event_list


# 증권신고서 
def corp_securities_info(input_corp, *args, start_year):

    securities_list = ['주식의포괄적교환이전', '합병', '증권예탁증권', '채무증권', '지분증권', '분할']
    
    element_list = []
    temp_securities_list = []

    for element in args:

        if element in securities_list:

            element_list.append(element)
            temp_securities = dart.regstate(input_corp, element, start_year)
            temp_securities_list.append(temp_securities)

    return element_list, temp_securities_list

# %%
dart.event('라이트론', '소송')
# Out:
#          rcept_no corp_cls corp_code corp_name  \
# 0  20200122000449        K  00367482      라이트론
# 1  20200211000486        K  00367482      라이트론
# 2  20200309000886        K  00367482      라이트론
# 3  20200304000800        K  00367482      라이트론
# 4  20210405002631        K  00367482      라이트론
# 5  20210617000054        K  00367482      라이트론
# 6  20200828000607        K  00367482      라이트론
# 7  20220128000556        K  00367482      라이트론
# 8  20210420000437        K  00367482      라이트론
# 9  20230106000734        K  00367482      라이트론
#
#                                  ft_ctp    cpct            cfd  \
# 0  당사는 소송대리인을 통하여 법적인 절차에 따라 대응할 예정입니다.  대전지방법원  2020년 01월 22일
# 1  당사는 소송대리인을 통하여 법적인 절차에 따라 대응할 예정입니다.  대전지방법원  2020년 02월 11일
# 2             당사는 법적인 절차에 따라 대응할 예정입니다.  대전지방법원  2020년 03월 09일
# 3  당사는 소송대리인을 통하여 법적인 절차에 따라 대응할 예정입니다.  대전지방법원  2020년 03월 04일
# 4  당사는 소송대리인을 통하여 법적인 절차에 따라 대응할 예정입니다.  대전지방법원  2021년 04월 05일
# ...

# %%
def corp_securities_info(input_corp, *args):

    securities_list = ['주식의포괄적교환이전', '합병', '증권예탁증권', '채무증권', '지분증권', '분할']
    
    element_list = []
    temp_event_list = []

    for element in args:

        if element in event_list:

            element_list.append(element)
            temp_event = dart.report(input_corp, element, input_year)
            temp_event_list.append(temp_event)

    return element_list, temp_event_list

# %%
corp_name = '삼성전자'
biz_num = 1248100998

temp = corp_confirm(corp_name,biz_num)

# %%
import datetime
